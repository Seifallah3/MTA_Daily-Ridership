# %% [markdown]
# <a href="https://colab.research.google.com/github/Seifallah3/MTA_Daily-Ridership/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/content/cars.csv')

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin Origin Model
# 0    3504          12.0     70     US        US 70
# 1    3693          11.5     70     US        US 70
# 2    3436          11.0     70     US        US 70
# 3    3433          12.0     70     US        US 70
# 4    3449          10.5     70     US        US 70

# %%
df.isna().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# Origin Model    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Car              object
# MPG             float64
# Cylinders         int64
# Displacement    float64
# Horsepower        int64
# Weight            int64
# Acceleration    float64
# Model             int64
# Origin           object
# Origin Model     object
# dtype: object

# %%
df.shape
# Out:
# (406, 10)

# %%
print("Rows where 'MPG' is 0:")
display(df[df['MPG'] == 0])
# Out:
# Rows where 'MPG' is 0:
#                                   Car  MPG  Cylinders  Displacement  \
# 10               Citroen DS-21 Pallas  0.0          4         133.0
# 11   Chevrolet Chevelle Concours (sw)  0.0          8         350.0
# 12                   Ford Torino (sw)  0.0          8         351.0
# 13            Plymouth Satellite (sw)  0.0          8         383.0
# 14                 AMC Rebel SST (sw)  0.0          8         360.0
# 17              Ford Mustang Boss 302  0.0          8         302.0
# 39        Volkswagen Super Beetle 117  0.0          4          97.0
# 367                         Saab 900s  0.0          4         121.0
#
#      Horsepower  Weight  Acceleration  Model  Origin Origin Model
# 10          115    3090          17.5     70  Europe    Europe 70
# 11          165    4142          11.5     70      US        US 70
# 12          153    4034          11.0     70      US        US 70
# 13          175    4166          10.5     70      US        US 70
# 14          175    3850          11.0     70      US        US 70
# 17          140    3353           8.0     70      US        US 70
# 39           48    1978          20.0     71  Europe    Europe 71
# 367         110    2800          15.4     81  Europe    Europe 81

# %%
print("\nRows where 'Horsepower' is 0:")
display(df[df['Horsepower'] == 0])
# Out:
# Rows where 'Horsepower' is 0:
#                       Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 38             Ford Pinto  25.0          4          98.0           0    2046
# 133         Ford Maverick  21.0          6         200.0           0    2875
# 337  Renault Lecar Deluxe  40.9          4          85.0           0    1835
# 343    Ford Mustang Cobra  23.6          4         140.0           0    2905
# 361           Renault 18i  34.5          4         100.0           0    2320
# 382        AMC Concord DL  23.0          4         151.0           0    3035
#
#      Acceleration  Model  Origin Origin Model
# 38           19.0     71      US        US 71
# 133          17.0     74      US        US 74
# 337          17.3     80  Europe    Europe 80
# 343          14.3     80      US        US 80
# 361          15.8     81  Europe    Europe 81
# 382          20.5     82      US        US 82

# %%
columns_with_zero = (df == 0).any()
print("Columns with zero values:")
print(columns_with_zero[columns_with_zero == True].index.tolist())
# Out:
# Columns with zero values:
# ['MPG', 'Horsepower']

# %%
# Sort DataFrame by 'Weight'
df_sorted_weight = df.sort_values(by='Weight', ascending=True)

# Get the bottom 20 cars by Weight (lightest)
df_bottom_20_weight = df_sorted_weight.head(20).copy()
df_bottom_20_weight['Weight Group'] = 'Bottom 20 Lightest'

# Get the top 20 cars by Weight (heaviest)
df_top_20_weight = df_sorted_weight.tail(20).copy()
df_top_20_weight['Weight Group'] = 'Top 20 Heaviest'

# Concatenate both DataFrames
df_combined_weight_groups = pd.concat([df_bottom_20_weight, df_top_20_weight])

print("Combined DataFrame for Top/Bottom 20 Weights (showing first 5 rows):")
display(df_combined_weight_groups.head())
# Out:
# Combined DataFrame for Top/Bottom 20 Weights (showing first 5 rows):
#                      Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 61           Datsun 1200  35.0          4          72.0          69    1613
# 151       Toyota Corolla  31.0          4          76.0          52    1649
# 350       Toyota Starlet  39.1          4          79.0          58    1755
# 352     Honda Civic 1300  35.1          4          81.0          60    1760
# 60   Toyota Corolla 1200  31.0          4          71.0          65    1773
#
#      Acceleration  Model Origin Origin Model        Weight Group
# 61           18.0     71  Japan     Japan 71  Bottom 20 Lightest
# 151          16.5     74  Japan     Japan 74  Bottom 20 Lightest
# 350          16.9     81  Japan     Japan 81  Bottom 20 Lightest
# 352          16.1     81  Japan     Japan 81  Bottom 20 Lightest
# 60           19.0     71  Japan     Japan 71  Bottom 20 Lightest

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler_weight = MinMaxScaler()
scaler_mpg = MinMaxScaler()

# Normalize 'Weight' (lower weight is better, so invert the score)
df['Normalized_Weight'] = 1 - scaler_weight.fit_transform(df[['Weight']])

# Normalize 'MPG' (higher MPG is better)
df['Normalized_MPG'] = scaler_mpg.fit_transform(df[['MPG']])

# Create a combined score (higher is better for both 'inverted' Weight and 'direct' MPG)
df['Combined_Weight_MPG_Score'] = df['Normalized_Weight'] + df['Normalized_MPG']

# Sort by Combined_Weight_MPG_Score in descending order and get the top 10
top_10_cars_weight_mpg = df.sort_values(by='Combined_Weight_MPG_Score', ascending=False).head(10)

print("Top 10 Cars by Combined Weight (inverted) and MPG Score:")
display(top_10_cars_weight_mpg[['Car', 'Weight', 'MPG', 'Combined_Weight_MPG_Score']].reset_index(drop=True))
# Out:
# Top 10 Cars by Combined Weight (inverted) and MPG Score:
#                                Car  Weight   MPG  Combined_Weight_MPG_Score
# 0              Honda Civic 1500 gl    1850  44.6                   1.879613
# 1                        Mazda GLC    2110  46.6                   1.859087
# 2     Volkswagen Rabbit C (Diesel)    2085  44.3                   1.805005
# 3  Volkswagen Rabbit Custom Diesel    1985  43.1                   1.801443
# 4             Renault Lecar Deluxe    1835  40.9                   1.785461
# 5                Volkswagen Pickup    2130  44.0                   1.784268
# 6                   Toyota Starlet    1755  39.1                   1.760271
# 7                   Plymouth Champ    1875  39.0                   1.723588
# 8                Volkswagen Rabbit    2144  41.5                   1.713809
# 9       Volkswagen Dasher (diesel)    2335  43.4                   1.710187

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Normalize 'Acceleration' and 'Horsepower'
df['Normalized_Acceleration'] = scaler.fit_transform(df[['Acceleration']])
df['Normalized_Horsepower'] = scaler.fit_transform(df[['Horsepower']])

# Create a combined score (higher is better for both)
df['Combined_Score'] = df['Normalized_Acceleration'] + df['Normalized_Horsepower']

# Sort by Combined_Score in descending order and get the top 10
top_10_cars = df.sort_values(by='Combined_Score', ascending=False).head(10)

print("Top 10 Cars by Combined Acceleration and Horsepower:")
display(top_10_cars[['Car', 'Acceleration', 'Horsepower', 'Combined_Score']].reset_index(drop=True))
# Out:
# Top 10 Cars by Combined Acceleration and Horsepower:
#                             Car  Acceleration  Horsepower  Combined_Score
# 0                      Hi 1200D          18.5         193        1.423913
# 1                     Ford F250          14.0         215        1.275621
# 2                     Chevy C20          15.0         200        1.253623
# 3                    Dodge D200          13.5         210        1.218685
# 4      Buick Electra 225 Custom          11.0         225        1.151398
# 5                AMC Concord DL          20.5         120        1.146222
# 6                   Peugeot 504          24.8          71        1.135870
# 7                 Buick Century          21.0         110        1.121636
# 8  Chrysler New Yorker Brougham          11.0         215        1.097050
# 9              Pontiac Catalina          10.0         225        1.091874

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e3cdb60-eab9-4089-9982-2c7c49c40c3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e3cdb60-eab9-4089-9982-2c7c49c40c3e")) {                    Plotly.newPlot(                        "4e3cdb60-eab9-4089-9982-2c7c49c40c3e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eWeight Group=Bottom 20 Lightest\u003cbr\u003eHorsepower=%{x}\u003cbr\u003eAcceleration=%{y}\u003cbr\u003eWeight (Scaled)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Datsun 1200","Toyota Corolla","Toyota Starlet","Honda Civic 1300","Toyota Corolla 1200","Honda Civic","Honda Civic CVCC","Ford Fiesta","Honda Civic CVCC","Renault 5 GTL","Volkswagen Rabbit","Volkswagen Model 111","Renault Lecar Deluxe","Volkswagen 1131 Deluxe Sedan","Toyota Corolla 1200","Volkswagen Rabbit","Honda Civic 1500 gl","Fiat 128","Plymouth Champ","Dodge Colt Hatchback Custom"],"legendgroup":"Bottom 20 Lightest","marker":{"color":"#636efa","size":[1613,1649,1755,1760,1773,1795,1795,1800,1800,1825,1825,1834,1835,1835,1836,1845,1850,1867,1875,1915],"sizemode":"area","sizeref":12.85,"symbol":"circle"},"mode":"markers","name":"Bottom 20 Lightest","orientation":"v","showlegend":true,"x":[69,52,58,60,65,53,53,66,60,58,71,60,55,46,65,62,67,49,64,80],"xaxis":"x","y":[18.0,16.5,16.9,16.1,19.0,17.4,17.5,14.4,16.4,18.6,12.2,19.0,17.3,20.5,21.0,15.3,13.8,19.5,16.4,14.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eWeight Group=Top 20 Heaviest\u003cbr\u003eHorsepower=%{x}\u003cbr\u003eAcceleration=%{y}\u003cbr\u003eWeight (Scaled)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chevrolet Caprice Classic","Plymouth Grand Fury","Oldsmobile Vista Cruiser","Buick LeSabre Custom","Ford F250","Mercury Marquis","Ford Gran Torino (sw)","Plymouth Custom Suburb","Ford LTD","Pontiac Catalina","Buick Century Luxus (sw)","Hi 1200D","Chrysler New Yorker Brougham","Ford Country Squire (sw)","Ford Country","Buick Electra 225 Custom","Mercury Marquis Brougham","Dodge Monaco (sw)","Chevrolet Impala","Pontiac Safari (sw)"],"legendgroup":"Top 20 Heaviest","marker":{"color":"#EF553B","size":[4464,4498,4499,4502,4615,4633,4638,4654,4657,4668,4699,4732,4735,4746,4906,4951,4952,4955,4997,5140],"sizemode":"area","sizeref":12.85,"symbol":"circle"},"mode":"markers","name":"Top 20 Heaviest","orientation":"v","showlegend":true,"x":[150,150,180,155,215,208,140,170,148,170,150,193,215,170,167,225,198,180,150,175],"xaxis":"x","y":[12.0,14.5,12.5,13.5,14.0,11.0,16.0,13.0,13.5,11.5,14.5,18.5,11.0,12.0,12.5,11.0,11.5,11.5,14.0,12.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %%
import numpy as np

# Get the indices of rows where 'MPG' is 0
zero_horsepower_indices = df[df['MPG'] == 0].index

print("Found 0 values in 'MPG' column. Please provide replacement values.")

for idx in zero_horsepower_indices:
    car_name = df.loc[idx, 'Car']
    print(f"\nCar: {car_name}")
    while True:
        try:
            new_hp = float(input(f"Enter new MPG for {car_name} (currently 0): "))
            if new_hp <= 0:
                print("MPG must be a positive number. Please try again.")
            else:
                df.loc[idx, 'MPG'] = new_hp
                break
        except ValueError:
            print("Invalid input. Please enter a numerical value for MPG.")

print("\nUpdated DataFrame after replacing 0 MPG values:")
display(df[df['MPG'] == 0])
print("Number of remaining zero MPG values:", (df['MPG'] == 0).sum())
# Out:
# Found 0 values in 'MPG' column. Please provide replacement values.
#
# Car: Citroen DS-21 Pallas
# Enter new MPG for Citroen DS-21 Pallas (currently 0): 25
#
# Car: Chevrolet Chevelle Concours (sw)
# Enter new MPG for Chevrolet Chevelle Concours (sw) (currently 0): 17.5
#
# Car: Ford Torino (sw)
# Enter new MPG for Ford Torino (sw) (currently 0): 17
#
# Car: Plymouth Satellite (sw)
# Enter new MPG for Plymouth Satellite (sw) (currently 0): 18
#
# Car: AMC Rebel SST (sw)
# Enter new MPG for AMC Rebel SST (sw) (currently 0): 16
#
# Car: Ford Mustang Boss 302
# Enter new MPG for Ford Mustang Boss 302 (currently 0): 18
#
# Car: Volkswagen Super Beetle 117
# Enter new MPG for Volkswagen Super Beetle 117 (currently 0): 26
#
# Car: Saab 900s
# Enter new MPG for Saab 900s (currently 0): 20.5
#
# Updated DataFrame after replacing 0 MPG values:
# Empty DataFrame
# Columns: [Car, MPG, Cylinders, Displacement, Horsepower, Weight, Acceleration, Model, Origin, Origin Model]
# Index: []
# Number of remaining zero MPG values: 0

# %%
print("\nRows where 'Horsepower' is 0:")
display(df[df['Horsepower'] == 0])
# Out:
# Rows where 'Horsepower' is 0:
# Empty DataFrame
# Columns: [Car, MPG, Cylinders, Displacement, Horsepower, Weight, Acceleration, Model, Origin, Origin Model]
# Index: []

# %%
import plotly.express as px

fig_mpg_cylinders = px.scatter(
    df,
    x='Cylinders',
    y='MPG',
    title='MPG vs. Cylinders',
    labels={'Cylinders': 'Number of Cylinders', 'MPG': 'Miles Per Gallon'},
    hover_data=['Car', 'Weight']
)
fig_mpg_cylinders.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f
],["AMC Matador",8,150],["Chevrolet Malibu",8,145],["Ford Gran Torino",8,137],["Dodge Coronet Custom",8,150],["Mercury Marquis Brougham",8,198],["Chevrolet Caprice Classic",8,150],["Ford LTD",8,158],["Plymouth Fury Gran Sedan",8,150],["Chrysler New Yorker Brougham",8,215],["Buick Electra 225 Custom",8,225],["AMC Ambassador Brougham",8,175],["Plymouth Valiant",6,105],["Chevrolet Nova Custom",6,100],["AMC Hornet",6,100],["Ford Maverick",6,88],["Plymouth Duster",6,95],["Volkswagen Super Beetle",4,46],["Chevrolet Impala",8,150],["Ford Country",8,167],["Plymouth Custom Suburb",8,170],["Oldsmobile Vista Cruiser",8,180],["AMC Gremlin",6,100],["Toyota Camry",4,88],["Chevrolet Vega",4,72],["Datsun 610",4,94],["Mazda RX3",3,90],["Ford Pinto",4,85],["Mercury Capri v6",6,107],["Fiat 124 Sport Coupe",4,90],["Chevrolet Monte Carlo S",8,145],[ ...

# %%
import plotly.express as px

# Calculate the average Horsepower for each country (Origin)
avg_horsepower_by_origin = df.groupby('Origin')['Horsepower'].mean().reset_index()

# Create a bar chart
fig_avg_horsepower_origin = px.bar(
    avg_horsepower_by_origin,
    x='Origin',
    y='Horsepower',
    title='Average Horsepower by Country of Origin',
    labels={'Origin': 'Country of Origin', 'Horsepower': 'Average Horsepower'},
    color='Origin' # Color bars by origin for better differentiation
)

fig_avg_horsepower_origin.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4160411-1a05-4ac8-b050-2c01ac08f6d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4160411-1a05-4ac8-b050-2c01ac08f6d8")) {                    Plotly.newPlot(                        "b4160411-1a05-4ac8-b050-2c01ac08f6d8",                        [{"alignmentgroup":"True","hovertemplate":"Country of Origin=%{x}\u003cbr\u003eAverage Horsepower=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":[80.83561643835617],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country of Origin=%{x}\u003cbr\u003eAverage Horsepower=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[79.83544303797468],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country of Origin=%{x}\u003cbr\u003eAverage Horsepower=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"v","showlegend":true,"textposition":"auto","x":["US"],"xaxis":"x","y":[119.82283464566929],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444 ...

# %%
import plotly.express as px

# Calculate the average MPG for each country (Origin)
avg_mpg_by_origin = df.groupby('Origin')['MPG'].mean().reset_index()

# Create a bar chart
fig_avg_mpg_origin = px.bar(
    avg_mpg_by_origin,
    x='Origin',
    y='MPG',
    title='Average MPG by Country of Origin',
    labels={'Origin': 'Country of Origin', 'MPG': 'Average Miles Per Gallon'},
    color='Origin' # Color bars by origin for better differentiation
)

fig_avg_mpg_origin.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40f9d8a9-b78b-45bb-a6bd-73dde335aff2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40f9d8a9-b78b-45bb-a6bd-73dde335aff2")) {                    Plotly.newPlot(                        "40f9d8a9-b78b-45bb-a6bd-73dde335aff2",                        [{"alignmentgroup":"True","hovertemplate":"Country of Origin=%{x}\u003cbr\u003eAverage Miles Per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":[27.724657534246578],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country of Origin=%{x}\u003cbr\u003eAverage Miles Per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[30.450632911392404],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country of Origin=%{x}\u003cbr\u003eAverage Miles Per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"v","showlegend":true,"textposition":"auto","x":["US"],"xaxis":"x","y":[20.028740157480314],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...
